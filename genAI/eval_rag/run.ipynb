# %%
import papermill as pm

# %%
# Run the generation notebook

# %%
parameters = {
    'data_store_id': 'moana-ds_1700038136331',
    'input_file': 'tsel_moana_golden.csv',
    'location': 'global',
    'project_id': 'mitochondrion-project-344303'
}

# %%
pm.execute_notebook(
    '[1]_rag_workflow.ipynb',
    'rag_output.ipynb',
    parameters=parameters
)
# Out:
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '79d38ceb-c0a6-4e75-bd2b-fb38ca64a8d0',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2023-12-04T03:20:21.515811',
#      'end_time': '2023-12-04T03:20:23.949832',
#      'duration': 2.434021,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-12-04T03:20:21.528643Z',
#      'iopub.execute_input': '2023-12-04T03:20:21.530045Z',
#      'shell.execute_reply': '2023-12-04T03:20:23.946842Z',
#      'iopub.status.idle': '2023-12-04T03:20:23.947678Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/tmp/ipykernel_22040/1615433721.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)\n  from tqdm.autonotebook import tqdm\n'}],
# ...

# %%
# Run the evaluation notebook

# %%
parameters = {
    'FILE_INPUT': 'tsel_moana_golden_gen_text-bison@latest.csv',
}

# %%
pm.execute_notebook(
    '[2]_eval_workflow.ipynb',
    'eval_output.ipynb',
    parameters=parameters
)
# Out:
# Executing:   0%|          | 0/13 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2023-12-04T03:21:52.822865',
#      'end_time': '2023-12-04T03:21:55.163231',
#      'duration': 2.340366,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2023-12-04T03:21:52.833804Z',
#      'iopub.execute_input': '2023-12-04T03:21:52.834474Z',
#      'iopub.status.idle': '2023-12-04T03:21:55.160941Z',
#      'shell.execute_reply': '2023-12-04T03:21:55.160001Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '/tmp/ipykernel_22577/3746026713.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)\n  from tqdm.autonotebook import tqdm\n'}],
# ...
